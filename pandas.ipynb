# %%
import pandas as pd

# Create a sample DataFrame
data = {
    'Name': ['Sanjana', 'Samruddhi', 'Akash', 'Vedanti'],
    'Age': [25, 30, 35, 40],
    'City': ['New York', 'London', 'Paris', 'Tokyo']
}

df = pd.DataFrame(data)

# Display the original DataFrame
print("Original DataFrame:")
print(df)

# Add a new column
df['Salary'] = [50000, 60000, 70000, 80000]
print("\nDataFrame after adding Salary column:")
print(df)

# Drop a column
df.drop('City', axis=1, inplace=True)
print("\nDataFrame after dropping City column:")
print(df)
# Out:
# Original DataFrame:
#         Name  Age      City
# 0    Sanjana   25  New York
# 1  Samruddhi   30    London
# 2      Akash   35     Paris
# 3    Vedanti   40     Tokyo
#
# DataFrame after adding Salary column:
#         Name  Age      City  Salary
# 0    Sanjana   25  New York   50000
# 1  Samruddhi   30    London   60000
# 2      Akash   35     Paris   70000
# 3    Vedanti   40     Tokyo   80000
#
# DataFrame after dropping City column:
#         Name  Age  Salary
# 0    Sanjana   25   50000
# 1  Samruddhi   30   60000
# 2      Akash   35   70000
# 3    Vedanti   40   80000

# %%
import matplotlib.pyplot as plt

# Bar chart to visualize names vs salaries
plt.figure(figsize=(8, 5))
plt.bar(df['Name'], df['Salary'], color='skyblue')
plt.title('Salary of Employees')
plt.xlabel('Name')
plt.ylabel('Salary')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
